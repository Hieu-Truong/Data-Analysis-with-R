# %% [markdown]
# <center><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300"></center><br/>
#
# # Assignment: Notebook for Peer Assignment
#
# Estimated time needed: 60 minutes

# %% [markdown]
# # Assignment Scenario
#
# Congratulations! You have just been hired by a US Weather forecast firm as a data scientist.
#
# The company is considering the weather condition to help predict the possibility of precipitations, which involves using various local climatological variables, including temperature, wind speed, humidity, dew point, and pressure. The data you will be handling was collected by a NOAA weather station located at the John F. Kennedy International Airport in Queens, New York.
#
# Your task is to provide a high level analysis of weather data in JFK Airport. Your stakeholders want to understand the current and historical record of precipitations based on different variables. For now they are mainly interested in a macro-view of JFK Airport Weather, and how it relates to the possibility to rain because it will affect flight delays and etc.

# %% [markdown]
# # Introduction
#
# This project relates to the NOAA Weather Dataset - JFK Airport (New York). The original dataset contains 114,546 hourly observations of 12 local climatological variables (such as temperature and wind speed) collected at JFK airport. This dataset can be obtained for free from the IBM Developer [Data Asset Exchange](https://developer.ibm.com/exchanges/data/all/jfk-weather-data/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0151ENSkillsNetwork926-2022-01-01).
#
# For this project, you will be using a subset dataset, which contains 5727 rows (about 5% or original rows) and 9 columns. The end goal will be to predict the precipitation using some of the available features. In this project, you will practice reading data files, preprocessing data, creating models, improving models and evaluating them to ultimately choose the best model.

# %% [markdown]
# ## Table of Contents:
#
# Using this R notebook you will complete **10 tasks**:
# * [0. Import Modules](#cell0)
# * [1. Download and Unzip NOAA Weather Dataset](#cell1)
# * [2. Read Dataset into Project](#cell2)
# * [3. Select Subset of Columns](#cell3)
# * [4. Clean Up Columns](#cell4)
# * [5. Convert Columns to Numerical Types](#cell5)
# * [6. Rename Columns](#cell6)
# * [7. Exploratory Data Analysis](#cell7)
# * [8. Linear Regression](#cell8)
# * [9. Improve the Model](#cell9)
# * [10. Find Best Model](#cell10)
#
#
# <a id="cell0"></a>
# ## 0. Import required modules
#
# Below, install "tidymodels", additionally "rlang" should be updated in order to properly run "tidymodels".

# %%
# Install tidymodels if you haven't done so
install.packages("tidyverse")
install.packages("rlang")
install.packages("tidymodels")
# Out:
# also installing the dependencies ‘bit’, ‘rappdirs’, ‘bit64’, ‘processx’, ‘memoise’, ‘blob’, ‘lifecycle’, ‘tidyselect’, ‘vctrs’, ‘data.table’, ‘scales’, ‘gargle’, ‘ids’, ‘cpp11’, ‘ellipsis’, ‘timechange’, ‘systemfonts’, ‘textshaping’, ‘vroom’, ‘tzdb’, ‘callr’, ‘stringi’, ‘broom’, ‘conflicted’, ‘cli’, ‘dbplyr’, ‘dplyr’, ‘dtplyr’, ‘forcats’, ‘ggplot2’, ‘googledrive’, ‘googlesheets4’, ‘haven’, ‘hms’, ‘httr’, ‘jsonlite’, ‘lubridate’, ‘magrittr’, ‘modelr’, ‘pillar’, ‘purrr’, ‘ragg’, ‘readr’, ‘readxl’, ‘reprex’, ‘rstudioapi’, ‘rvest’, ‘stringr’, ‘tibble’, ‘tidyr’, ‘xml2’
#
# Warning message in install.packages("tidyverse"):
# “installation of package ‘systemfonts’ had non-zero exit status”Warning message in install.packages("tidyverse"):
# “installation of package ‘textshaping’ had non-zero exit status”Warning message in install.packages("tidyverse"):
# “installation of package ‘ragg’ had non-zero exit status”Warning message in install.packages("tidyverse"):
# ...

# %% [markdown]
# **Note: After installing the packages, restart the kernel. Without installing the packages again, load them. Tidyverse and Tidymodels will be the two main packages you will use.**

# %%
# Library for modeling
library(tidymodels)

# Load tidyverse
library(tidyverse)
# Out:
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.0 ──
# ✔ broom     0.5.6      ✔ recipes   0.1.12
# ✔ dials     0.0.6      ✔ rsample   0.0.5
# ✔ dplyr     0.8.5      ✔ tibble    3.0.1
# ✔ ggplot2   3.3.0      ✔ tune      0.1.0
# ✔ infer     0.5.1      ✔ workflows 0.1.1
# ✔ parsnip   0.1.0      ✔ yardstick 0.0.6
# ✔ purrr     0.3.4
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ purrr::discard()  masks scales::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ ggplot2::margin() masks dials::margin()
# ✖ recipes::step()   masks stats::step()
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ✔ stringr 1.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ readr::col_factor() masks scales::col_factor()
# ✖ purrr::discard()    masks scales::discard()
# ...

# %% [markdown]
# ### Understand the Dataset
#
# The original NOAA JFK dataset contains 114,546 hourly observations of various local climatological variables (including temperature, wind speed, humidity, dew point, and pressure).
#
# In this project you will use a sample dataset, which is around 293 KB. [Link to the sample dataset](https://dax-cdn.cdn.appdomain.cloud/dax-noaa-weather-data-jfk-airport/1.1.4/noaa-weather-sample-data.tar.gz).
#
# The sample contains 5727 rows (about 5% or original rows) and 9 columns, which are:
# - DATE
# - HOURLYDewPointTempF
# - HOURLYRelativeHumidity
# - HOURLYDRYBULBTEMPF
# - HOURLYWETBULBTEMPF
# - HOURLYPrecip
# - HOURLYWindSpeed
# - HOURLYSeaLevelPressure
# - HOURLYStationPressure
#
# The original dataset is much bigger. Feel free to explore the original dataset. [Link to the original dataset.](https://dax-cdn.cdn.appdomain.cloud/dax-noaa-weather-data-jfk-airport/1.1.4/noaa_weather.html)
#
# For more information about the dataset, checkout the [preview](https://dax-cdn.cdn.appdomain.cloud/dax-noaa-weather-data-jfk-airport/1.1.4/data-preview/index.html?_ga=2.176781478.281508226.1616293518-1509963377.1616117067&cm_mc_uid=90945889198916153255549&cm_mc_sid_50200000=64650651616293516933) of NOAA Weather - JFK Airport.

# %% [markdown]
# <a id="cell1"></a>
#
# ## 1. Download NOAA Weather Dataset
#
# Use the `download.file()` function to download the sample dataset from the URL below.
#
# URL = 'https://dax-cdn.cdn.appdomain.cloud/dax-noaa-weather-data-jfk-airport/1.1.4/noaa-weather-sample-data.tar.gz'

# %%
url <- 'https://dax-cdn.cdn.appdomain.cloud/dax-noaa-weather-data-jfk-airport/1.1.4/noaa-weather-sample-data.tar.gz'
download.file(url, destfile = "noaa-weather-sample-data.tar.gz")

# %% [markdown]
# Untar the zipped file.

# %%
untar("noaa-weather-sample-data.tar.gz", tar = "internal")
# Out:
# Warning message in untar2(tarfile, files, list, exdir, restore_times):
# “using pax extended headers”

# %% [markdown]
# <a id="cell2"></a>
# ## 2. Extract and Read into Project
# We start by reading in the raw dataset. You should specify the file name as "noaa-weather-sample-data/jfk_weather_sample.csv".

# %%
weather_sample <- read.csv("noaa-weather-sample-data/jfk_weather_sample.csv")

# %% [markdown]
# Next, display the first few rows of the dataframe.

# %%
head(weather_sample, 1)
# Out:
#   DATE                 HOURLYDewPointTempF HOURLYRelativeHumidity
# 1 2015-07-25T13:51:00Z 60                  46
#   HOURLYDRYBULBTEMPF HOURLYWETBULBTEMPF HOURLYPrecip HOURLYWindSpeed
# 1 83                 68                 0.00         13
#   HOURLYSeaLevelPressure HOURLYStationPressure
# 1 30.01                  29.99

# %% [markdown]
# Also, take a `glimpse` of the dataset to see the different column data types and make sure it is the correct subset dataset with about 5700 rows and 9 columns.

# %%
glimpse(weather_sample)
# Out:
# Rows: 5,727
# Columns: 9
# $ DATE                   <fct> 2015-07-25T13:51:00Z, 2016-11-18T23:51:00Z, 20…
# $ HOURLYDewPointTempF    <fct> 60, 34, 33, 18, 27, 35, 4, 14, 51, 71, 76, 19,…
# $ HOURLYRelativeHumidity <int> 46, 48, 89, 48, 61, 79, 51, 65, 90, 94, 79, 37…
# $ HOURLYDRYBULBTEMPF     <int> 83, 53, 36, 36, 39, 41, 19, 24, 54, 73, 83, 44…
# $ HOURLYWETBULBTEMPF     <int> 68, 44, 35, 30, 34, 38, 15, 21, 52, 72, 78, 35…
# $ HOURLYPrecip           <fct> 0.00, 0.00, 0.00, 0.00, T, 0.00, 0.00, 0.00, 0…
# $ HOURLYWindSpeed        <int> 13, 6, 13, 14, 11, 6, 0, 11, 11, 5, 21, 7, 17,…
# $ HOURLYSeaLevelPressure <dbl> 30.01, 30.05, 30.14, 29.82, NA, 29.94, 30.42, …
# $ HOURLYStationPressure  <dbl> 29.99, 30.03, 30.12, 29.80, 30.50, 29.92, 30.4…

# %% [markdown]
# <a id="cell3"></a>
# ## 3. Select Subset of Columns
#
# The end goal of this project will be to predict `HOURLYprecip` (precipitation) using a few other variables. Before you can do this, you first need to preprocess the dataset. Section 3 to section 6 focuses on preprocessing.
#
# The first step in preprocessing is to select a subset of data columns and inspect the column types.
#
# The key columns that we will explore in this project are:
# - HOURLYRelativeHumidity
# - HOURLYDRYBULBTEMPF
# - HOURLYPrecip
# - HOURLYWindSpeed
# - HOURLYStationPressure
#
# Data Glossary:
# - 'HOURLYRelativeHumidity' is the relative humidity given to the nearest whole percentage.
# - 'HOURLYDRYBULBTEMPF' is the dry-bulb temperature and is commonly used as the standard air temperature reported. It is given here in whole degrees Fahrenheit.
# - 'HOURLYPrecip' is the amount of precipitation in inches to hundredths over the past hour. For certain automated stations, precipitation will be reported at sub-hourly intervals (e.g. every 15 or 20 minutes) as an accumulated amount of all precipitation within the preceding hour. A “T” indicates a trace amount of precipitation.
# - 'HOURLYWindSpeed' is the speed of the wind at the time of observation given in miles per hour (mph).
# - 'HOURLYStationPressure' is the atmospheric pressure observed at the station during the time of observation. Given in inches of Mercury (in Hg).
#
# `Select` those five columns and store the modified dataframe as a new variable.

# %%
weather_sample_select <- weather_sample %>%
select(HOURLYRelativeHumidity,HOURLYDRYBULBTEMPF,HOURLYPrecip,HOURLYWindSpeed,HOURLYStationPressure)

# %% [markdown]
# Show the first 10 rows of this new dataframe.

# %%
head(weather_sample_select, 10)
# Out:
#    HOURLYRelativeHumidity HOURLYDRYBULBTEMPF HOURLYPrecip HOURLYWindSpeed
# 1  46                     83                 0.00         13
# 2  48                     53                 0.00          6
# 3  89                     36                 0.00         13
# 4  48                     36                 0.00         14
# 5  61                     39                 T            11
# 6  79                     41                 0.00          6
# 7  51                     19                 0.00          0
# 8  65                     24                 0.00         11
# 9  90                     54                 0.06         11
# 10 94                     73                 NA            5
#    HOURLYStationPressure
# 1  29.99
# 2  30.03
# 3  30.12
# 4  29.80
# 5  30.50
# 6  29.92
# 7  30.40
# 8  30.35
# 9  30.03
# 10 29.91

# %% [markdown]
# <a id="cell4"></a>
# ## 4. Clean Up Columns
#
# From the dataframe preview above, we can see that the column `HOURLYPrecip` - which is the hourly measure of precipitation levels - contains both `NA` and `T` values. `T` specifies *trace amounts of precipitation* (meaning essentially no precipitation), while `NA` means *not available*, and is used to denote missing values. Additionally, some values also have "s" at the end of them, indicating that the precipitation was snow.
#
# Inspect the unique values present in the column `HOURLYPrecip` (with `unique(dataframe$column)`) to see these values.

# %%
unique(weather_sample_select$HOURLYPrecip)
# Out:
#  [1] 0.00  T     0.06  <NA>  0.03  0.02  0.08  0.01  0.07  0.16  0.09  0.22
# [13] 0.02s 0.24  0.18  0.05  0.04  0.09s 0.11  0.14  0.25  0.10  0.01s 0.58
# [25] 0.12  0.13  0.46  1.07  1.19  0.34  0.20  0.36s 0.42  0.17  0.27  0.35
# [37] 0.31  0.33  0.23  0.26  0.28  0.75  0.19  0.36  0.03s 0.07s 0.54  0.59
# [49] 0.21
# 48 Levels: 0.00 0.01 0.01s 0.02 0.02s 0.03 0.03s 0.04 0.05 0.06 0.07 ... T

# %% [markdown]
# Having characters in values (like the "T" and "s" that you see in the unique values) will cause problems when you create a model because values for precipitation should be numerical. So you need to fix these values that have characters.
#
# Now, for the column `HOURLYPrecip`:
# 1. Replace all the `T` values with "0.0" and
# 2. Remove "s" from values like "0.02s". In R, you can use the method `str_remove(column, pattern = "s$")` to remove the character "s" from the end of values. The "$" tells R to match to the end of values. The `pattern` is a regex pattern. Look at [here](https://www.rdocumentation.org/packages/stringi/versions/1.5.3/topics/about_search_regex?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0151ENSkillsNetwork926-2022-01-01) for more information about regex and matching to strings in R.
#
# Remember that you can use `tidyverse`'s  `mutate()` to update columns.
#
# You can check your work by checking if unique values of `HOURLYPrecip` still contain any `T` or `s`. Store the modified dataframe as a new variable.

# %%
weather_sample_replace <- weather_sample_select %>% 
mutate(HOURLYPrecip = ifelse(HOURLYPrecip == "T", 0.0, HOURLYPrecip)) %>%
mutate(HOURLYPrecip = stringr::str_remove(HOURLYPrecip, pattern = "s$"))

unique(weather_sample_replace$HOURLYPrecip)
# Out:
#  [1] "1"  "0"  "10" NA   "6"  "4"  "13" "2"  "11" "21" "14" "27" "5"  "29" "23"
# [16] "9"  "8"  "15" "17" "20" "30" "16" "3"  "43" "18" "19" "41" "46" "47" "36"
# [31] "25" "39" "40" "22" "32" "37" "34" "35" "28" "31" "33" "45" "24" "38" "7"
# [46] "12" "42" "44" "26"

# %% [markdown]
# <a id="cell5"></a>
# ## 5. Convert Columns to Numerical Types
# Now that you have removed the characters in the `HOURLYPrecip` column, you can safely covert the column to a numeric type.
#
# First, check the types of the columns. You will notice that all are `dbl` (double or numeric) except for `HOURLYPrecip`, which is `chr` (character or string). Use the `glimpse` function from Tidyverse.

# %%
glimpse(weather_sample_replace)
# Out:
# Rows: 5,727
# Columns: 5
# $ HOURLYRelativeHumidity <int> 46, 48, 89, 48, 61, 79, 51, 65, 90, 94, 79, 37…
# $ HOURLYDRYBULBTEMPF     <int> 83, 53, 36, 36, 39, 41, 19, 24, 54, 73, 83, 44…
# $ HOURLYPrecip           <chr> "1", "1", "1", "1", "0", "1", "1", "1", "10", …
# $ HOURLYWindSpeed        <int> 13, 6, 13, 14, 11, 6, 0, 11, 11, 5, 21, 7, 17,…
# $ HOURLYStationPressure  <dbl> 29.99, 30.03, 30.12, 29.80, 30.50, 29.92, 30.4…

# %% [markdown]
# Convert `HOURLYPrecip` to the `numeric` type and store the cleaned dataframe as a new variable.

# %%
weather_sample_convert <- weather_sample_replace %>%
mutate(HOURLYPrecip = as.numeric(HOURLYPrecip))

# %% [markdown]
# We can now see that all fields have numerical data type.

# %%
glimpse(weather_sample_convert)
# Out:
# Rows: 5,727
# Columns: 5
# $ HOURLYRelativeHumidity <int> 46, 48, 89, 48, 61, 79, 51, 65, 90, 94, 79, 37…
# $ HOURLYDRYBULBTEMPF     <int> 83, 53, 36, 36, 39, 41, 19, 24, 54, 73, 83, 44…
# $ HOURLYPrecip           <dbl> 1, 1, 1, 1, 0, 1, 1, 1, 10, NA, NA, 1, 1, 1, 1…
# $ HOURLYWindSpeed        <int> 13, 6, 13, 14, 11, 6, 0, 11, 11, 5, 21, 7, 17,…
# $ HOURLYStationPressure  <dbl> 29.99, 30.03, 30.12, 29.80, 30.50, 29.92, 30.4…

# %% [markdown]
# <a id="cell6"></a>
# ## 6. Rename Columns
# Let's rename the following columns as:
# - 'HOURLYRelativeHumidity' to 'relative_humidity'
# - 'HOURLYDRYBULBTEMPF' to 'dry_bulb_temp_f'
# - 'HOURLYPrecip' to 'precip'
# - 'HOURLYWindSpeed' to 'wind_speed'
# - 'HOURLYStationPressure' to 'station_pressure'
#
# You can use `dplyr::rename()`. Then, store the final dataframe as a new variable.

# %%
weather_sample_rename <- weather_sample_convert %>%
rename(relative_humidity = HOURLYRelativeHumidity,
       dry_bulb_temp_f = HOURLYDRYBULBTEMPF,
       precip = HOURLYPrecip,
       wind_speed = HOURLYWindSpeed,
       station_pressure = HOURLYStationPressure)
glimpse(weather_sample_rename)
# Out:
# Rows: 5,727
# Columns: 5
# $ relative_humidity <int> 46, 48, 89, 48, 61, 79, 51, 65, 90, 94, 79, 37, 72,…
# $ dry_bulb_temp_f   <int> 83, 53, 36, 36, 39, 41, 19, 24, 54, 73, 83, 44, 57,…
# $ precip            <dbl> 1, 1, 1, 1, 0, 1, 1, 1, 10, NA, NA, 1, 1, 1, 1, 1, …
# $ wind_speed        <int> 13, 6, 13, 14, 11, 6, 0, 11, 11, 5, 21, 7, 17, 8, 3…
# $ station_pressure  <dbl> 29.99, 30.03, 30.12, 29.80, 30.50, 29.92, 30.40, 30…

# %% [markdown]
# <a id="cell7"></a>
# ## 7. Exploratory Data Analysis
# Now that you have finished preprocessing the dataset, you can can start exploring the columns more.
#
# First, split the data into a training and testing set. Splitting a dataset is done randomly, so to have reproducible results set the seed = 1234. Also, use 80% of the data for training.

# %%
set.seed(1234)
split <- initial_split(weather_sample_rename, prob = 0.8)
train_df <- training(split)
test_df <- testing(split)

# %% [markdown]
# Next, looking at just the **training set**, plot histograms or box plots of the variables (`relative_humidity`, `dry_bulb_temp_f`, `precip`, `wind_speed`,  `station_pressure`) for an intial look of their distributions using `tidyverse`'s `ggplot`. Leave the testing set as is because it is good practice to not see the testing set until evaluating the final model.

# %%
# box plot of variable relative_humidity in training set
ggplot(data = subset(train_df, !is.na(relative_humidity)),mapping = aes(y = relative_humidity)) +
geom_boxplot() +
labs(x = "Box plot of relative humidity")

# box plot of dry-bulb temperture in training set
ggplot(data = subset(train_df, !is.na(dry_bulb_temp_f)), mapping = aes(y = dry_bulb_temp_f)) +
geom_boxplot() +
labs(x = "Box plot of dry-bulb temperture")

# histogram of precipitation in training set
ggplot(data = subset(train_df, !is.na(precip)), mapping = aes( x= precip)) +
geom_histogram(binwidth = 1) +
labs(x = "Histogram of the precipitation ")

# Box plot of wind speed in training set
ggplot(data = subset(train_df, !is.na(wind_speed)), mapping = aes( y= wind_speed)) +
geom_boxplot() +
labs(x = "Histogram of the wind speed")

# Box plot of station pressure in training set
ggplot(data = subset(train_df, !is.na(station_pressure)), mapping = aes(y= station_pressure)) +
geom_boxplot() +
labs(x = "Histogram of the atmospheric pressure")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# <a id="cell8"></a>
# ## 8. Linear Regression
# After exploring the dataset more, you are now ready to start creating models to predict the precipitation (`precip`).
#
# Create simple linear regression models where `precip` is the response variable and each of `relative_humidity`, `dry_bulb_temp_f`,`wind_speed` or `station_pressure` will be a predictor variable, e.g. `precip ~ relative_humidity`, `precip ~ dry_bulb_temp_f`, etc. for a total of four simple models.
# Additionally, visualize each simple model with a scatter plot.

# %%
# simple linear model 
model_1 <- lm(precip ~ relative_humidity, data= weather_sample_rename)
summary(model_1)
# scatter plot
ggplot(train_df, aes(x = relative_humidity, y = precip)) +
  geom_point() +
  geom_smooth(method = "lm", formula = y ~ x, color = "green") +
  labs(title = "Scatter Plot with Linear Regression Model",
       x = "relative humidity",
       y = "precipitation")
# Out:
# Call:
# lm(formula = precip ~ relative_humidity, data = weather_sample_rename)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -3.209 -1.273 -0.515  0.242 43.970
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -1.247512   0.196570  -6.346 2.45e-10 ***
# relative_humidity  0.044562   0.002853  15.618  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.618 on 4065 degrees of freedom
#   (1660 observations deleted due to missingness)
# Multiple R-squared:  0.05661,	Adjusted R-squared:  0.05638
# F-statistic: 243.9 on 1 and 4065 DF,  p-value: < 2.2e-16
# Warning message:
# “Removed 1246 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 1246 rows containing missing values (geom_point).”
# plot without title

# %%
# simple model
model_2 <- lm(precip ~ dry_bulb_temp_f, data = weather_sample_rename)
summary(model_2)

# scatter plot
ggplot(train_df, aes(dry_bulb_temp_f, precip)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  labs(title = "Scatter Plot with Linear Regression Model",
       x = "dry-bulb tempreture",
       y = "precipitation")
# Out:
# Call:
# lm(formula = precip ~ dry_bulb_temp_f, data = weather_sample_rename)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -1.736 -0.712 -0.690 -0.670 45.323
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      1.758335   0.196081   8.967   <2e-16 ***
# dry_bulb_temp_f -0.001198   0.003376  -0.355    0.723
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.725 on 4065 degrees of freedom
#   (1660 observations deleted due to missingness)
# Multiple R-squared:  3.098e-05,	Adjusted R-squared:  -0.000215
# F-statistic: 0.1259 on 1 and 4065 DF,  p-value: 0.7227
# `geom_smooth()` using formula 'y ~ x'
# Warning message:
# “Removed 1246 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 1246 rows containing missing values (geom_point).”
# plot without title

# %%
# simple linear model
model_3 <- lm(precip ~ wind_speed, data = weather_sample_rename)
summary(model_3)

# scatter plot
ggplot(train_df, aes(wind_speed, precip)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  labs(title = "Scatter Plot with Linear Regression Model",
       x = "wind speed",
       y = "precipitation")
# Out:
# Call:
# lm(formula = precip ~ wind_speed, data = weather_sample_rename)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -3.995 -0.960 -0.620 -0.394 44.701
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.055207   0.120004   8.793  < 2e-16 ***
# wind_speed  0.056525   0.009319   6.065 1.44e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.708 on 4065 degrees of freedom
#   (1660 observations deleted due to missingness)
# Multiple R-squared:  0.008969,	Adjusted R-squared:  0.008725
# F-statistic: 36.79 on 1 and 4065 DF,  p-value: 1.436e-09
# `geom_smooth()` using formula 'y ~ x'
# Warning message:
# “Removed 1246 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 1246 rows containing missing values (geom_point).”
# plot without title

# %%
# simple linear model
model_4 <- lm(precip ~ station_pressure, data = weather_sample_rename)
summary(model_4)

# scatter plot
ggplot(train_df, aes(station_pressure, precip)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  labs(title = "Scatter Plot with Linear Regression Model",
       x = "station pressure",
       y = "precipitation")
# Out:
# Call:
# lm(formula = precip ~ station_pressure, data = weather_sample_rename)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -4.933 -1.053 -0.655 -0.171 44.550
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)       76.1659     7.2426   10.52   <2e-16 ***
# station_pressure  -2.4829     0.2414  -10.28   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.677 on 4061 degrees of freedom
#   (1664 observations deleted due to missingness)
# Multiple R-squared:  0.02538,	Adjusted R-squared:  0.02514
# F-statistic: 105.7 on 1 and 4061 DF,  p-value: < 2.2e-16
# `geom_smooth()` using formula 'y ~ x'
# Warning message:
# “Removed 1249 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 1249 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# <a id="cell9"></a>
# ## 9. Improve the Model
# Now, try improving the simple models you created in the previous section.
#
# Create at least two more models, each model should use at least one of the different techniques:
# 1. Add more features/predictors
# 2. Add regularization (L1, L2 or a mix)
# 3. Add a polynomial component
#
# Also, for each of the models you create, check the model performance using the **training set** and a metric like MSE, RMSE, or R-squared.
#
# Consider using `tidymodels` if you choose to add regularization and tune lambda.

# %%
# multiple liner regression model
model_5 <- lm(precip ~ relative_humidity + wind_speed + dry_bulb_temp_f +  station_pressure, data = train_df)
summary(model_5)
# calculate rmse
mse_model_5<- mean(model_5$residual^2)
rmse_model_5 <- sqrt(mse_model_5)
print(rmse_model_5)
# polynominal model
model_6 <- lm(precip ~ poly(relative_humidity,3, raw = TRUE), data = train_df)
summary(model_6)
#calculate rmse
mse_model_6 <- mean(model_6$residual^2)
rmse_model_6 <- sqrt(mse_model_6)
print(rmse_model_6)
# Out:
# Call:
# lm(formula = precip ~ relative_humidity + wind_speed + dry_bulb_temp_f +
#     station_pressure, data = train_df)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -6.881 -1.273 -0.478  0.325 42.801
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)       26.122516   9.262881   2.820  0.00483 **
# relative_humidity  0.050145   0.003541  14.159  < 2e-16 ***
# wind_speed         0.075943   0.011696   6.493 9.77e-11 ***
# dry_bulb_temp_f   -0.008390   0.003920  -2.141  0.03239 *
# station_pressure  -0.937595   0.302497  -3.100  0.00196 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.577 on 3042 degrees of freedom
#   (1249 observations deleted due to missingness)
# Multiple R-squared:  0.08767,	Adjusted R-squared:  0.08647
# F-statistic: 73.08 on 4 and 3042 DF,  p-value: < 2.2e-16
# [1] 3.574081
# Call:
# lm(formula = precip ~ poly(relative_humidity, 3, raw = TRUE),
# ...

# %% [markdown]
# <a id="cell10"></a>
# ## 10. Find Best Model
# Compare the regression metrics of each model from section 9 to find the best model overall. To do this,
#
# 1. Evaluate the models on the **testing set** using at least one metric (like MSE, RMSE or R-squared).
# 2. After calculating the metrics on the testing set for each model, print them out in as a table to easily compare. You can use something like:
# ```
# model_names <- c("model_1", "model_2", "model_3")
# train_error <- c("model_1_value", "model_2_value", "model_3_value")
# test_error <- c("model_1_value", "model_2_value", "model_3_value")
# comparison_df <- data.frame(model_names, train_error, test_error)
# ```
# 3. Finally, from the comparison table you create, conclude which model performed the best.

# %%
# create train results for model 5
train_fit_model_5 <- predict(model_5, newdata = train_df)
train_result_model_5 <- data_frame(truth = train_df$precip, predict_value = train_fit_model_5)
# calculate rmse and r- squared for train set
rmse_train_model_5 <- rmse(train_result_model_5, truth = truth, estimate = predict_value)$.estimate
r_squared_train_model_5 <- rsq(train_result_model_5, truth = truth, estimate = predict_value)$.estimate

# create test results for model 5
test_fit_model_5 <- predict(model_5, newdata = test_df)
test_result_model_5 <- data.frame( truth = test_df$precip, predict_value = test_fit_model_5)

# calculate rmse and r-squared for test set
rmse_test_model_5 <- rmse(test_result_model_5, truth = truth, estimate = predict_value)$.estimate
r_squared_test_model_5 <- rsq(test_result_model_5, truth = truth, estimate = predict_value)$.estimate

# create train results of model 6
train_fit_model_6 <- predict(model_6, newdata = train_df)
train_result_model_6 <- data_frame(truth = train_df$precip, predict_value = train_fit_model_6)

# calculate rmse and r- squared for train set
rmse_train_model_6 <- rmse(train_result_model_6, truth = truth, estimate = predict_value)$.estimate
r_squared_train_model_6 <- rsq(train_result_model_6, truth = truth, estimate = predict_value)$.estimate

# create test results of model 6
test_fit_model_6 <- predict(model_6, newdata = test_df)
test_result_model_6 <- data.frame(truth = test_df$precip, predict_value = test_fit_model_6)

# calculate rmse and r-squared of model 6 for test set 
rmse_test_model_6 <- rmse(test_result_model_6, truth = truth, estimate = predict_value)$.estimate
r_squared_test_model_6 <- rsq(test_result_model_6, truth = truth, estimate = predict_value)$.estimate

# create table to comparing two modles
model_names <- c("model 5", "model_6")
train_rmse <- c(rmse_train_model_5, rmse_train_model_6)
test_rmse <- c(rmse_test_model_5, rmse_test_model_6)
train_rsquared <- c(r_squared_train_model_5, r_squared_train_model_6)
test_rsquared <- c(r_squared_test_model_5, r_squared_test_model_6)
comparison_df <- data.frame(model_names, train_rmse, test_rmse, train_rsquared, test_rsquared)
print(comparison_df)

# Base on RMSE and Rsquared on train data. It is clear that Model 6 fits train data better than Model 5.
# However,
# RMSE of Model 5  on test data is lower than it's RMSE on train data, so this model performs well to predicting new data.
# By contrast, Model 6 produces a higher RMSE on test data compared to the RMSE on train data.
# The R-squared of Model 5 on test data is larger than the R square of model 6 on test data
# Therefore,model 5 performs overall slightly better than Model 6 for prediction with new data.
# Out:
#   model_names train_rmse test_rmse train_rsquared test_rsquared
# 1     model 5   3.574081  3.543365     0.08766592    0.06882859
# 2     model_6   3.538543  3.590485     0.10605732    0.05080937

# %% [markdown]
# ## Author(s)
#
# <h4> Yiwen Li </h4>
#
# ## Contributions
#
# <h4> Tiffany Zhu </h4>
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
